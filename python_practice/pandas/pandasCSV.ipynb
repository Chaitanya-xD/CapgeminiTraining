# %%
import pandas as pd

# %%
df = pd.read_csv('people.csv')

# %%
df.head(3)
# Out:
#    Index First Name Last Name     Sex                  Email  \
# 0      1     Shelby   Terrell    Male   elijah57@example.net
# 1      2    Phillip   Summers  Female  bethany14@example.com
# 2      3   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title
# 0  001-084-906-7849x73518    1945-10-26  Games developer
# 1       214.112.6044x4913    1910-03-24   Phytotherapist
# 2            277.609.7938    1992-07-02        Homeopath

# %%
#Converting to JSON
df_json = df.head(3) 
df_json = df_json.to_json()
df_json
# Out:
# '{"Index":{"0":1,"1":2,"2":3},"First Name":{"0":"Shelby","1":"Phillip","2":"Kristine"},"Last Name":{"0":"Terrell","1":"Summers","2":"Travis"},"Sex":{"0":"Male","1":"Female","2":"Male"},"Email":{"0":"elijah57@example.net","1":"bethany14@example.com","2":"bthompson@example.com"},"Phone":{"0":"001-084-906-7849x73518","1":"214.112.6044x4913","2":"277.609.7938"},"Date of birth":{"0":"1945-10-26","1":"1910-03-24","2":"1992-07-02"},"Job Title":{"0":"Games developer","1":"Phytotherapist","2":"Homeopath"}}'

# %%
df.sort_values(by='Last Name',ascending=True)
# Out:
#     Index First Name   Last Name     Sex                    Email  \
# 32     33     Bonnie     Andrews  Female    caitlin24@example.net
# 44     45     Darren     Andrews    Male   lhernandez@example.com
# 74     75        Kim     Andrews  Female    wpetersen@example.org
# 76     77   Jonathon    Atkinson    Male   gailfrench@example.net
# 87     88     Dustin      Bailey    Male      pbarron@example.net
# ..    ...        ...         ...     ...                      ...
# 56     57   Courtney     Watkins  Female       ochang@example.org
# 29     30     Norman       Weber    Male      mconrad@example.com
# 38     39    Cynthia     Wiggins  Female  rosariodave@example.org
# 84     85      Helen  Williamson  Female     melvin08@example.net
# 69     70     Sandra          Wu    Male       ubanks@example.com
#
#                    Phone Date of birth                             Job Title
# 32  +1-253-987-2776x9161    1953-12-21                   Seismic interpreter
# ...

# %%
#Converting to HTML
df_html = df.head(1) 
df_html = df_html.to_html()
df_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Index</th>\n      <th>First Name</th>\n      <th>Last Name</th>\n      <th>Sex</th>\n      <th>Email</th>\n      <th>Phone</th>\n      <th>Date of birth</th>\n      <th>Job Title</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>1</td>\n      <td>Shelby</td>\n      <td>Terrell</td>\n      <td>Male</td>\n      <td>elijah57@example.net</td>\n      <td>001-084-906-7849x73518</td>\n      <td>1945-10-26</td>\n      <td>Games developer</td>\n    </tr>\n  </tbody>\n</table>'

# %%
df[df['Index'] == 1]
# Out:
#    Index First Name Last Name   Sex                 Email  \
# 0      1     Shelby   Terrell  Male  elijah57@example.net
#
#                     Phone Date of birth        Job Title
# 0  001-084-906-7849x73518    1945-10-26  Games developer
